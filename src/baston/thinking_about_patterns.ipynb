# %% [markdown]
# # Thinking about Patterns

# %% [markdown]
# I have a hard time finding a satisfying syntax for patterns in Python that uses operator overloading for composition.
# - Python has introduced `@` as a new optional operator that you can override with `__mathmul__`

# %%
from baston import *
# Out:
# Output device: Haut-parleurs MacBook Pro (44100Hz, buffer size 256 samples, 2 channels)
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# Error in _func: int() argument must be a string, a bytes-like object or a real number, not 'list'
# ...

# %%
p0 * n(
    note=Pn(0, 7, 5, 3) & (Pn(0, 0, 0, 5) | Pn(-7, 0, 5, 3)),
    velocity=Psine(1/2, 80, 127).int(),
    dur=Peuclid(5, 8) / 4 & Pseq(1, Rest(1) / 2)
)

# %%
p0 * n(
    note=Psine(1, 50, 120) | Psine(2, 40, 80) | Psine(3, 30, 60),
    velocity=Psine(1/2, 80, 127).int(),
    dur=Peuclid(5, 8) / 4 & Pseq(1, Rest(1) / 2)
)

# %%
# Out:
# [[0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4],
#  [0, 1, 2, 2, 3, 4]]
